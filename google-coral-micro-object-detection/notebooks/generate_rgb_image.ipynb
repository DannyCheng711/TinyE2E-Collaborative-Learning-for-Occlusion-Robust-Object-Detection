# %% [markdown]
# # Convert .jpg into .rgb image

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (2.8.0)
# Requirement already satisfied: filelock in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torch) (4.14.1)
# Requirement already satisfied: setuptools in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torch) (2025.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (0.23.0)
# Requirement already satisfied: numpy in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: torch==2.8.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torchvision) (2.8.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: filelock in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torch==2.8.0->torchvision) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torch==2.8.0->torchvision) (4.14.1)
# Requirement already satisfied: setuptools in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torch==2.8.0->torchvision) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torch==2.8.0->torchvision) (1.14.0)
# Requirement already satisfied: networkx in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torch==2.8.0->torchvision) (3.5)
# Requirement already satisfied: jinja2 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torch==2.8.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from torch==2.8.0->torchvision) (2025.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch==2.8.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from jinja2->torch==2.8.0->torchvision) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from opencv-python) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (6.31.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (3.11.2)
# Requirement already satisfied: numpy>=1.26.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (2.2.6)
# Requirement already satisfied: h5py>=3.11.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.8.2)
# Requirement already satisfied: pillow in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (14.1.0)
# Requirement already satisfied: namex in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/Danny/Desktop/ICL/Thesis_Program/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
from pathlib import Path
import numpy as np
import tensorflow as tf
import glob
import os
import random

# %% [markdown]
# ## Object detection

# %%
def preprocess_image_quantized(img_path, output_path, resolution, scale, zero_point, dtype):
    """
    Matches PyTorch ToTensor() preprocessing:
    - Resize to (resolution,resolution)
    - Convert to RGB
    - Scale to [0,1] float
    - Quantize to int8/uint8 with given scale & zero_point
    - Save as raw .rgb file in NHWC
    """
    # Load and resize
    image = Image.open(img_path).convert('RGB')
    image = image.resize((resolution, resolution), Image.BILINEAR)

    # ToTensor() behavior: float32 in [0,1]
    x = np.array(image, dtype=np.float32) / 255.0   # [H,W,3]

    # Quantize
    if dtype.lower() == "uint8":
        q = np.round(x / scale + zero_point).clip(0, 255).astype(np.uint8)
    elif dtype.lower() == "int8":
        q = np.round(x / scale + zero_point).clip(-128, 127).astype(np.int8)
    else:
        raise ValueError("dtype must be 'uint8' or 'int8'")

    # Add batch dim: [1,H,W,3]
    q = np.expand_dims(q, axis=0)

    # Save
    q.tofile(output_path)
    print(f"[OK] Saved quantized NHWC to {output_path} shape={q.shape} dtype={q.dtype} scale={scale} zp={zero_point}")

# %%
def reconstruct_quantized_rgb(rgb_bin_path, out_jpeg_path, resolution, scale, zero_point, dtype):
    # Determine numpy dtype from quantized dtype string
    np_dtype = np.uint8 if dtype.lower() == "uint8" else np.int8
    print(f"[INFO] Reading as {np_dtype}")

    # Read binary and reshape to NHWC
    q = np.fromfile(rgb_bin_path, dtype=np_dtype).reshape(1, resolution, resolution, 3)

    # Dequantize to float [0,255]
    x = (q.astype(np.float32) - float(zero_point)) * float(scale) * 255.0  # match ToTensor() inverse

    # Clip to valid range and convert to uint8
    x = np.clip(x, 0, 255).astype(np.uint8)

    # Convert to PIL Image (drop batch dim)
    img = Image.fromarray(x[0])
    img.save(out_jpeg_path, format="JPEG")
    print(f"[OK] Reconstructed preview to {out_jpeg_path}, shape={x[0].shape}, dtype=uint8")

# %%
model_path   = "./yolo_mcunet_model.tflite"
src_jpeg_dir = "./images"
out_rgb_dir  = "./rgb_images"
out_preview_dir = "./preview_images"

# %%
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()[0]
input_shape = input_details["shape"]  # [1, H, W, 3]
H, W = int(input_shape[1]), int(input_shape[2])
if input_shape[-1] != 3:
    raise ValueError(f"Expected 3 channels, got {input_shape[-1]}")
input_scale, input_zp = input_details["quantization"]
dtype_np = input_details["dtype"]
if dtype_np == np.int8:
    dtype_str = "int8"
elif dtype_np == np.uint8:
    dtype_str = "uint8"
else:
    raise ValueError(f"Unsupported dtype: {dtype_np}")

print(f"Model input: {H}x{W}x3  dtype={dtype_str}  scale={input_scale}  zp={input_zp}")
# Out:
# Model input: 160x160x3  dtype=int8  scale=0.003921568859368563  zp=-128

# %%
jpgs = sorted(glob.glob(os.path.join(src_jpeg_dir, "*.jpg")))
if not jpgs:
    raise FileNotFoundError(f"No .jpg files found under {src_jpeg_dir}")
random.seed(42)
sample = random.sample(jpgs, k=100)
print(f"Selected {len(sample)} images from {len(jpgs)} available.")
# Out:
# Selected 100 images from 1981 available.

# %%
index = []
for idx, jpg in enumerate(sample, 1):
    stem = Path(jpg).stem
    out_rgb_path = os.path.join(out_rgb_dir, f"{stem}_q_{H}.rgb")
    preprocess_image_quantized(
        jpg, out_rgb_path, H, input_scale, input_zp, dtype_str
    )

    preview_path = None
    if out_preview_dir:
        preview_path = os.path.join(out_preview_dir, f"{stem}_preview.png")
        reconstruct_quantized_rgb(out_rgb_path, preview_path, H, input_scale, input_zp, dtype_str)
# Out:
# [OK] Saved quantized NHWC to ./rgb_images/2012_002893_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002893_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000567_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000567_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000139_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000139_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003351_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003351_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001281_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001281_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001150_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001150_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001063_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001063_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000695_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000695_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003327_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003327_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000523_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000523_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003067_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003067_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003349_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003349_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_004038_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_004038_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002449_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002449_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000455_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000455_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002656_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002656_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001950_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001950_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000177_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000177_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000168_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000168_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000485_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000485_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001046_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001046_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001104_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001104_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002302_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002302_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002718_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002718_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000150_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000150_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002527_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002527_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000956_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000956_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003225_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003225_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002935_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002935_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003168_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003168_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001935_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001935_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001055_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001055_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002068_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002068_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002653_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002653_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001294_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001294_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003664_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003664_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003947_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003947_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000040_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000040_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003434_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003434_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003656_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003656_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000783_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000783_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003159_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003159_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001954_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001954_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001576_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001576_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000767_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000767_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001030_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001030_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_004291_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_004291_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003448_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003448_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001560_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001560_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000481_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000481_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001730_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001730_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000500_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000500_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001654_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001654_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003841_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003841_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001595_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001595_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002725_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002725_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001232_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001232_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003659_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003659_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000242_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000242_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003299_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003299_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002116_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002116_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002421_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002421_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000627_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000627_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_004133_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_004133_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001724_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001724_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000405_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000405_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002482_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002482_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001368_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001368_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003748_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003748_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002843_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002843_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002789_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002789_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_004009_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_004009_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003916_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003916_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001660_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001660_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002595_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002595_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000917_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000917_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003178_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003178_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000368_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000368_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000262_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000262_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002986_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002986_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001081_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001081_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003498_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003498_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001349_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001349_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000410_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000410_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003878_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003878_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003937_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003937_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000516_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000516_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002091_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002091_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_002878_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_002878_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003782_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003782_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001670_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001670_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_000797_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_000797_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001688_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001688_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001642_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001642_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001005_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001005_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003031_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003031_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_001245_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_001245_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003170_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003170_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_004192_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_004192_preview.png, shape=(160, 160, 3), dtype=uint8
# [OK] Saved quantized NHWC to ./rgb_images/2012_003093_q_160.rgb shape=(1, 160, 160, 3) dtype=int8 scale=0.003921568859368563 zp=-128
# [INFO] Reading as <class 'numpy.int8'>
# [OK] Reconstructed preview to ./preview_images/2012_003093_preview.png, shape=(160, 160, 3), dtype=uint8
